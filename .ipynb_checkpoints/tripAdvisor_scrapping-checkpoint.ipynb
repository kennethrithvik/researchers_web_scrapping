# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
filename = "hello.txt"
file = open(filename, "w")

# %%
html= requests.get('https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-Universal_Studios_Singapore-Sentosa_Island.html#REVIEWS')
soup=bs(html.text,'html.parser')
reviewDivs = soup.find_all("div", {"class": "review-container"})
html2= requests.get('https://www.tripadvisor.com.sg/Attraction_Review-g294264-d2439664-Reviews-or10-Universal_Studios_Singapore-Sentosa_Island.html')
soup2=bs(html2.text,'html.parser')
reviewDivs2=soup2.find_all("div", {"class": "review-container"})
reviewDivs=reviewDivs[:]+reviewDivs2[:]
for review in reviewDivs:
    try:
        if review.div.div.div.find('span',{"class": "userLocation"}) :
            location=review.div.div.div.find('span',{"class": "userLocation"}).text+",null"
        else:
            location="null,null"
        userName=review.div.div.div.find('span',{"class": "scrname"}).text
        reviewText=review.div.div.div.find('p',{"class": "partial_entry"}).text
        reviewTitle=review.div.div.div.find('span',{"class": "noQuotes"}).text
        rating=review.div.div.div.find('div',{"class": "rating"}).span['class'][1]
        rating=int(rating.split('_')[1])/10.0
        user=review.div.div.div.find('div',{"class": "memberBadgingNoText"})
        postCount=user.find_all('span',{"class":"badgetext"})[0].text
        usefulVotes=user.find_all('span',{"class":"badgetext"})[1].text
        print "Review Title = "+reviewTitle    
        print "Review Text = "+reviewText
        print "User Name = "+userName
        print "Location :- { city: "+location.split(',')[0]+" , country: "\
                            +location.split(',')[1]+" }"
        print "Rating = ",rating
        #file.write("Rating = "+str(rating))
        print "No. of posts by user = ",postCount
        print "No. of useful votes by user = ",usefulVotes
        print "\n\n"
    except Exception as ex:
        print ex
file.close()
# Out:
# Review Title = A must do
# Review Text = Awesome day at Universal, much better than the theme parks in Australia. Everything there is quality and you feel like you are in the movies. We lined up at 9:30am and gates open at 10am, there was a bit of a line but got straight...More
# User Name = griffyn2010
# Location :- { city: Melbourne , country:  Australia }
# Rating =  5.0
# No. of posts by user =  15
# No. of useful votes by user =  2
#
#
#
# Review Title = Great and exhausting
# Review Text = First we did Transformers because after 11am you will wait for at least an hour. That was fantastic! After Transformers we did Revenge of the Mummy and few more things before lunch. Around noon place is crowded and for all good rides you will wait...More
# User Name = KKKK2810
# Location :- { city: Osijek , country:  Croatia }
# Rating =  4.0
# No. of posts by user =  30
# No. of useful votes by user =  6
#
#
#
# Review Title = Universal Studios - physically exhausting
# Review Text = Great place for all ages. But long lines for all rides. No line for Express tickets, but that is expensive. Senior citizens have 50% discount.
# User Name = Ashok J
# Location :- { city: Gurugram (Gurgaon) , country:  India }
# Rating =  5.0
# No. of posts by user =  25
# No. of useful votes by user =  9
#
#
#
# list index out of range
# Review Title = Park is undersized. Not goo organisation. You can only enjoy 6pm to 8pm
# Review Text = Attractions are extremely nice, but the amount of people is too much vs. what the park can handle. Lines start when you arrive to the park and you will be lucky if you can do more than 2 attractions in the morning. It is true...More
# User Name = pintoejd
# Location :- { city: Geneva , country:  Switzerland }
# Rating =  2.0
# No. of posts by user =  49
# No. of useful votes by user =  22
#
#
#
# Review Title = Fun Family Day out
# Review Text = The hype for Universal Studios Singapore for being the first Univeral Studio Park in South East Asia is totally true. Having 5 different theme zones, each having their different (theme based) rides. Be sure to collect the show timing as they are a must to...More
# User Name = Asif J
# Location :- { city: null , country: null }
# Rating =  4.0
# No. of posts by user =  30
# No. of useful votes by user =  11
#
#
#
# Review Title = So wanted to go and see how it stacked up to LA, but was disappointed
# Review Text = Smaller than LA, but has the same razzmatazz and glitz. One major disappointment and something for international visitors is the on line booking service. It needs to be more transparent with both instructions to process your reservation and where you need to go. Oh, and...More
# User Name = John B
# Location :- { city: Adelaide , country:  Australia }
# Rating =  3.0
# No. of posts by user =  37
# No. of useful votes by user =  5
#
#
#
# Review Title = Lost for words
# Review Text = Amazing place to be. Go for the 2 day fun play pass according to what all you want visit in Sentosa. But my suggestion if you are going on a Friday Saturday Sunday or a public holiday make sure to take the express pass. Head...More
# User Name = Divit B
# Location :- { city: Mumbai , country:  India }
# Rating =  5.0
# No. of posts by user =  18
# No. of useful votes by user =  7
#
#
#
# list index out of range
# Review Title = A good day out
# Review Text = It's a nice short day trip but not so many rides for people who love them. You end up repeating many of the same. There are free lockers but often you get stuck inside waiting in the queue and so this can mean you might...More
# User Name = Ryan G
# Location :- { city: London , country:  United Kingdom }
# Rating =  3.0
# No. of posts by user =  78
# No. of useful votes by user =  16
#
#
#
# Review Title = Overhyped theme park that is average
# Review Text = One of the main reasons for coming to Singapore was to visit Universal Studios Singapore (USS).
# The website,marketing and reviews gave us the impression that it is world class and rides are fabulous. Sadly the reality is that except for 3 or 4 rides/attractions the...More
# User Name = Mohammed L
# Location :- { city: Johannesburg , country:  South Africa }
# Rating =  3.0
# No. of posts by user =  58
# No. of useful votes by user =  36
#
#
#
# Review Title = Big disappointment.
# Review Text = Too crowded, long queue, extremely hot, coming back from here my son suffered from high fever........
# User Name = Luke Leeroy L
# Location :- { city: null , country: null }
# Rating =  1.0
# No. of posts by user =  48
# No. of useful votes by user =  23
#
#
#
# Review Title = Impeccable!!! Super must visit
# Review Text = This place is the supreme best I have ever visited on earth.
# You get a feel of your fantasy as well.. so much adventure rides with transformers, mummy ride being best..
# The place is always crowded and might take a lot of time in queue....More
# User Name = Rohit G
# Location :- { city: Delhi , country:  Delhi }
# Rating =  5.0
# No. of posts by user =  48
# No. of useful votes by user =  12
#
#
#
# Review Title = A Wonderful day out
# Review Text = Universal Studios Singapore at Sentosa Island is a must visit place while you are in Singapore. The best thing I like about Universal Studios is that it delivers on the thrill and excitement. The rides at Universal are so thrilling and they add so much...More
# User Name = Jainam M
# Location :- { city: Mumbai , country:  India }
# Rating =  4.0
# No. of posts by user =  60
# No. of useful votes by user =  14
#
#
#
# Review Title = Big Scam
# Review Text = USS is a big scam for making money. U need to buy express ticket along with entry ticket since average wait time is 60+ mins for any ride irrespective of a weekday. There is a long queue for everything inspite is paying so much money....More
# User Name = CSMuralidhar
# Location :- { city: Sydney , country:  Australia }
# Rating =  1.0
# No. of posts by user =  3
# No. of useful votes by user =  3
#
#
#
# Review Title = Great Day Out
# Review Text = After reading other reviews, we had purchased and printed our tickets in advance and changed the day we had planned to go from a Friday to a Thursday to avoid it being overly busy.
# We arrived prior to 10am (again as read from other reviews)...More
# User Name = Chima0291
# Location :- { city: null , country: null }
# Rating =  4.0
# No. of posts by user =  74
# No. of useful votes by user =  28
#
#
#
# Review Title = First time but not my last
# Review Text = Universal studios Singapore was excellent. For my first time I was rarely let down with all the rides open with the exception of the Waterworld attraction but it didn’t matter as me and my partner had a great time!
# The best ride for me was...More
# User Name = Rob W
# Location :- { city: null , country: null }
# Rating =  4.0
# No. of posts by user =  16
# No. of useful votes by user =  11
#
#
#
# list index out of range
# Review Title = Great place for kids
# Review Text = We had a 24 hour stop over in Singapore and decided to come here. Wish we stayed longer. Loved the theme pro and the facilities it had around it. Some advice, buy your tickets online through other sale agents much cheaper, definitely worth buying VIP...More
# User Name = Hale T
# Location :- { city: Sydney , country:  Australia }
# Rating =  4.0
# No. of posts by user =  51
# No. of useful votes by user =  15
#
#
#
# Review Title = The other Universal Studios Parks are better
# Review Text = If I had to choose out of all 4 Universal Studios parks, Singapore would be the last pick. The entire park felt cramped and messy? No better way to describe it. And the park itself wasn't even packed as students were still in school at...More
# User Name = espresso_based
# Location :- { city: null , country: null }
# Rating =  3.0
# No. of posts by user =  20
# No. of useful votes by user =  4
